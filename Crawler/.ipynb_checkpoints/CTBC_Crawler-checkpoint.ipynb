# %%
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
def linkInfoCrawler(target):
    df = pd.DataFrame(columns = ['Date', 'Title', 'Link'])
    driver = webdriver.Chrome(executable_path=r'/Users/chenboyu/Desktop/野村投信/chromedriver')
    driver.get('https://www.cnbc.com/search/?query=' + str(target) + '&qsearchterm=' + str(target))
    time.sleep(3)

    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(1)

        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            links = driver.find_elements_by_css_selector('a.resultlink')
            if(len(links) >= 4250):
                break
        last_height = new_height
    
    htmlSource = driver.page_source
    return htmlSource

# %%
target = 'blockchain'
driver = webdriver.Chrome(executable_path=r'/Users/chenboyu/Desktop/野村投信/chromedriver')
driver.get('https://www.cnbc.com/search/?query=' + str(target) + '&qsearchterm=' + str(target))
time.sleep(3)
htmlSource = driver.page_source

# %%
htmlSource
# Out:
# '<html lang="en" prefix="og=https://ogp.me/ns#" itemtype="https://schema.org/WebPage"><head><script type="text/javascript" src="https://nbcu.demdex.net/event?d_nsid=0&amp;d_ld=_ts%3D1589624294197&amp;d_rtbd=json&amp;d_jsonv=1&amp;d_dst=1&amp;d_cb=demdexRequestCallback_0_1589624294197&amp;c_nbcu_brand=cnbc&amp;c_nbcu-cnbc-contenttype=wildcard&amp;c_nbcu_cleantitle=search&amp;c_mps_contentid=106&amp;c_mps_path=%2Fid%2F106&amp;c_mps-cnbc-cats=search&amp;c_mps-cnbc-cat1=search&amp;c_mps_admode=gpt-asynchronous&amp;c_mps_adlazyload=1&amp;c_mps_cag-cnbc-template=wildcard&amp;c_mps_cag-cnbc-brand=cnbc&amp;c_mps_cag-cnbc-section=search&amp;c_mps_cag-cnbc-datePublished=1525361420&amp;c_mps_cag-cnbc-dateLastPublished=1579723677&amp;c_mps_cag-cnbc-dateFirstPublished=1525361420&amp;c_mps_field-cnbc-pubdate=1525361420&amp;c_mps_fwssid=fw_search&amp;c_mps_loadset=0&amp;c_mps_adunitid=%2F2620%2Fnbcu.cnbc%2Fsearch&amp;c_mps_refdomain=cnbc.com&amp;c_pagename=cnbc%7Cwildcard%7Csearch%7C106%7Csearch&amp;c_pageName=106%7Csearch&amp;c_contextData_cnbc_pageURL=https%3A%2F%2Fwww.cnbc.com%2Fsearch%2F%3Fquery%3Dblockchain%26qsearchterm%3Dblockchain&amp;c_contextData_cnbc_cleanurl=www.cnbc.com%2Fsearch%2F&amp;c_contextData_cnbc_tags=NA&amp;c_contextData_cnbc_project=NA&amp;c_contextData_cnbc_team=NA&amp;c_contextData_cnbc_template=wildcard&amp;c_contextData_cnbc_brand=cnbc&amp;c_contextData_cnbc_assetstatus=Unrestricted&amp;c_contextData_cnbc_contenttype=wildcard&amp;c_contextData_cnbc_section=Search&amp;c_contextData_cnbc_sectiontype=section&amp;c_contextData_cnbc_creator=NA&amp;c_contextData_cnbc_hier1=search&amp;c_contextData_cnbc_hier2=NA&amp;c_contextData_cnbc_hier3=NA&amp;c_contextData_cnbc_hier4=NA&amp;c_contextData_cnbc_hier5=NA&amp;c_contextData_cnbc_id=106&amp;c_contextData_cnbc_source=NA&amp;c_contextData_cnbc_firstpubdate=05%2F03%2F2018&amp;c_contextData_cnbc_lastpubdate=01%2F22%2F2020&amp;c_contextData_cnbc_dateline=05%2F03%2F2018&amp;c_contextData_cnbc_creatoroverwrite=NA&amp;c_contextData_cnbc_additionalsections=NA&amp;c_contextData_cnbc_platform=web&amp;c_contextData_cnbc_usagerule=NA&amp;c_contextData_cnbc_packaging=NA&amp;c_contextData_cnbc_xfinityheader=false&amp;c_contextData_tve_did=demdex%20cookie%20not%20set&amp;c_contextData_cnbc_hour=6%3A00AM&amp;c_contextData_cnbc_day=Saturday&amp;c_contextData_cnbc_daytype=Weekend&amp;c_contextData_cnbc_mid=51626027465617798450740618729759068297&amp;c_contextData_cnbc_newrepmon=New&amp;c_contextData_cnbc_newrep90=New&amp;c_contextData_cnbc_sessionnumber=1"></script><script src="https://pagead2.googlesyndication.com/pagead/show_companion_ad.js"></script><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script async="" src="//static.ads-twitter.com/uwt.js"></script><script src="https://connect.facebook.net/signals/config/212491672506947?v=2.9.18&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://acidpigs.com/v2/0/cfgPonIZy0vzBw2WwDUYHDKQ6jLZ5cQibbFroY_JQFu4xDnvmXqd8OEvwhd_5aVLhuUfg"></script><script src="https://fm.cnbc.com/applications/cnbc.com/resources/files/2020/03/28/VisitorAPI.js"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script src="https://www.googletagservices.com/tag/js/gpt.js" async="" type="text/javascript"></script><script type="text/javascript" async="" src="//cdn.tinypass.com/api/tinypass.min.js"></script><script type="text/javascript" defer="" src="https://dashboard.tinypass.com/xbuilder/experience/load?aid=o19WonOrHQ"></script><script src="//mps.cnbc.com/fetch/ext/load-cnbc-web.js?nowrite=2" id="mps-gpt-shared" class="mps-script"></script><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/icomoon.ttf" type="font/ttf" crossorigin="anonymous"><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/351C86_0_0.woff2" type="font/woff2" crossorigin ...
